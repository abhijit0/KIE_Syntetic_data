# %%
import json
import numpy as np

# %%
root_dir = 'all_annotations/dekra_annotations/'
annotations_dir = f'{root_dir}/annotations/instances_default.json'
image_dir = f'{root_dir}/images'

# %% [markdown]
# ## Keys to include

# %%
all_keys = ["anlagenummer","prüfgrundlage","objectstandort", "objectkart_anlage", "Fabrik_nr", "eigennummer", "eigenname", "arbeitgeber", "verwendete_messegeräte",
"baujahr",
"wartungsfirma",
"tragfähigkeit",
"errichtungsgrundlage",
"haltstellen_zugangstellen",
"geschwindigkeit",
"antrieb_aufhängung",
"förderhöhe",
"ergebnis_der_prüfung",
"betreiber",
"Prüfsystem",
"nächste_prüfung",
"datum_der_prüfung",
"Liegenschaft",
"Straße",
"Stadt",
"vertragsnummer",
"serviceorder",
"objektangabe",
"leistungsdatum",
"anlagentyp",
"durchgeführt_von",
"plz",
"technikers_mängelanzeige",
"equipment_nummer",
"aufstrags_nummer",
"kunden_nummer",
"akten_nummer",
"leistungsort",
"leistungsempfänger",
"inventar_nr",
"prüfort",
"standort",
"hertsteller",
"ausführende_firma",
"betriebsteil",
"kostenst_betreiber",
"standort_b_kunden"]

keys_needed = ["anlagenummer","objectstandort", "Fabrik_nr", "eigennummer", "eigenname", "arbeitgeber",
"baujahr",
"wartungsfirma",
"tragfähigkeit",
"haltstellen_zugangstellen",
"geschwindigkeit",
"förderhöhe",
"ergebnis_der_prüfung",
"betreiber",
"nächste_prüfung",
"datum_der_prüfung",
"Straße",
"Stadt",
"vertragsnummer",
"leistungsdatum",
"durchgeführt_von",
"plz",
"technikers_mängelanzeige",
"equipment_nummer",
"aufstrags_nummer",
"kunden_nummer",
"akten_nummer",
"leistungsort",
"inventar_nr",
"prüfort",
"standort",
"hertsteller",
"ausführende_firma"]

# %%
key_classification_no_re = {
    "hertsteller":["hertsteller"],
    "baujahr":["baujahr"],
    "seiriennummer":["Fabrik_nr", "equipment_nummer"],
    "inventorynummber" : ["anlagenummer"],
    "ort": ["objectstandort", "Straße", "Stadt", "plz","standort", "leistungsort","prüfort"],
    "mangelstatus":["ergebnis_der_prüfung"],
    "wartungsdatum":["leistungsdatum"],   
    "checkup_date":["datum_der_prüfung"],
    "nächste_prüfung":["nächste_prüfung"],
    "servicefirma":["wartungsfirma","ausführende_firma"],
    "contact_person":["durchgeführt_von", "technikers_mängelanzeige"],
    "tragfähigkeit":["tragfähigkeit"],
    "anzahl_haltestellen":["haltstellen_zugangstellen"],
    "Förderhöhe":["förderhöhe"],
    "nenngeschwindigkeit":["geschwindigkeit"],
    "vertrag_wartung":["vertragsnummer", "aufstrags_nummer"]
}

# %%
print(keys_needed)
# Out:
# ['anlagenummer', 'objectstandort', 'Fabrik_nr', 'eigennummer', 'eigenname', 'arbeitgeber', 'baujahr', 'wartungsfirma', 'tragfähigkeit', 'haltstellen_zugangstellen', 'geschwindigkeit', 'förderhöhe', 'ergebnis_der_prüfung', 'betreiber', 'nächste_prüfung', 'datum_der_prüfung', 'Straße', 'Stadt', 'vertragsnummer', 'leistungsdatum', 'durchgeführt_von', 'plz', 'technikers_mängelanzeige', 'equipment_nummer', 'aufstrags_nummer', 'kunden_nummer', 'akten_nummer', 'leistungsort', 'inventar_nr', 'prüfort', 'standort', 'hertsteller', 'ausführende_firma']

# %%
#with open(annotations_dir) as f:
#        configs = json.load(f)
        
#print(configs.keys())

# %%
#configs['categories']

# %%
from utility_functions.utilities_kie import * 
#tokenizer = AutoTokenizer.from_pretrained("microsoft/layoutxlm-base")
#model = AutoModel.from_pretrained("microsoft/layoutxlm-base")

tokenizer = AutoTokenizer.from_pretrained("tokenizer_added_tokens")
model = AutoModel.from_pretrained("model_added_tokens")
# Out:
# Some weights of the model checkpoint at model_added_tokens were not used when initializing LayoutLMv2Model: ['extractor.rel_classifier.bilinear.weight', 'extractor.ffnn_tail.0.weight', 'extractor.ffnn_tail.3.bias', 'extractor.ffnn_tail.3.weight', 'extractor.ffnn_head.3.bias', 'extractor.ffnn_head.3.weight', 'extractor.entity_emb.weight', 'extractor.ffnn_head.0.bias', 'extractor.rel_classifier.linear.weight', 'extractor.rel_classifier.linear.bias', 'extractor.ffnn_head.0.weight', 'extractor.ffnn_tail.0.bias']
# - This IS expected if you are initializing LayoutLMv2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LayoutLMv2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import pickle

def preprocess_tokens(tokens:list=None, bboxes:list=None):
    speical_characters = set(string.punctuation)
    tokens_preprocessed = []
    bboxes_preprocessed = []
        
    for i, token in enumerate(tokens):
        token = token.lower()
        for char_ in speical_characters:
            token = token.strip(char_)
        if token not in speical_characters and token not in (' ',  '', '\t','\n') and len(token) > 0:
            tokens_preprocessed.append(token)
            bboxes_preprocessed.append(bboxes[i])
        
    return tokens_preprocessed, bboxes_preprocessed

def load_annotation_image(image_id:int=None, configs:dict=None):
    annotations = []
    for annotation in configs["annotations"]:
        if annotation["image_id"] == image_id:
            annotations.append(annotation)
    return annotations
        
def load_category(category_id:int=None, configs:dict=None):
    for category in configs["categories"]:
        if category["id"] == category_id:
            return category
                    

def label_tokens_no_re(annotation, category, bbox, labels_no_re):
    labels_no_re_rearranged = rearrange_labels_no_re(labels_no_re=labels_no_re)
    labels_no_re_temp = {}

    for key, _ in labels_no_re.items():
        labels_no_re_temp[f'{key}_key'] = []
        labels_no_re_temp[f'{key}_val'] = []
    label2id = {key:i+1 for i, (key,_) in enumerate(labels_no_re_temp.items())}
    label2id['Other']=0

    annotation_attributes = annotation['attributes']
    #bbox = postprocess_bobx(annotation['bbox'])
    text = annotation_attributes['content']
    tokens, _, _ = split_text_bboxes(bbox, text, category)
    labels = []
    #category_temp = category[:category.rfind('_')]
    for _ in range(len(tokens)):
        #print(f'category {category}')
        category_temp = category[:category.rfind('_')]
        #print(f'category_temp {category_temp}')
        #print('-----')
        if category_temp in labels_no_re_rearranged.keys():
            if 'key' in category:
                key_index = f'{labels_no_re_rearranged[category_temp]}_key'
                label_key = label2id[key_index]
                labels.append(label_key)
            elif 'value' in category:
                val_index = f'{labels_no_re_rearranged[category_temp]}_val'
                label_val = label2id[val_index]
                labels.append(label_val)
        else:
            labels.append(label2id['Other'])
    #print(labels)
    return labels 

def label_input_ids_no_re(tokens:list, tokens_input_ids_map:dict, labels_tokens):
    labels_no_re = []
    for i,token in enumerate(tokens):
        #print(bboxes[1])
        #print(f'len(token) {len(token)}')
        #input_ids, _, _ = encode_tokens(tokens=[token], bboxes=[bboxes[i]], tokenizer=tokenizer)
        input_ids = tokens_input_ids_map[token]
        token_label = labels_tokens[i]
        labels_tokens_local = [token_label for _ in range(len(input_ids))]
        labels_no_re.extend(labels_tokens_local)
    
    return labels_no_re
def postprocess_bobx(bbox, image_dim):
    bbox_postprocessed = []
    
    #for i in bbox:
    #    if i - float(int(i)) < 0.5:
    #        val = int(np.floor(i))
    #        bbox_postprocessed.append(val)
    #    else:
    #        val = int(np.ceil(i))
    #        bbox_postprocessed.append(val)
    bbox_postprocessed = [bbox[0], bbox[1], bbox[0]+bbox[2], bbox[1]+bbox[3]]
    
    bbox_postprocessed = normalize_bbox(bbox_postprocessed, width=image_dim['width'], height = image_dim['height'])
    
    return bbox_postprocessed


def split_text_bboxes(bbox, text, category):
    #print(text)
    tokens = text.split(' ')
    bboxes = [bbox for _ in range(len(tokens))]
    tokens, bboxes = preprocess_tokens(tokens=tokens, bboxes=bboxes)
    categories = [category for _ in range(len(tokens))]
    return tokens, bboxes, categories

def form_entities(token_cat_groups, tokenizer, input_ids, input_id_map):
    entities = {'start':[], 'end':[], 'label':[], 'cat':[]}
    label_vals_simplified = {"OTHER": 0, "QUESTION" : 1, "ANSWER" : 2}
    #print(token_cat_groups)
    for token_cat_group in token_cat_groups:
        token_group = token_cat_group[0]
        cat_group = token_cat_group[1]
        
        if len(cat_group) >0 and len(token_group) >0:
            cat = cat_group[0]
        
            input_ids_token_group = [input_id_map[tokenized_token] for token in token_group for tokenized_token in tokenizer.tokenize(token) if tokenized_token in input_id_map.keys()]
            indexes = find_sequnce_indices(sequence=input_ids_token_group, input_ids=input_ids)

            if len(indexes)>0:
                start_idx = indexes[0][0]
                end_idx = indexes[0][-1]
        
                entities['start'].append(start_idx)  
                entities['end'] .append(end_idx)
                if '_key' in cat:
                    entities['label'].append(label_vals_simplified['QUESTION'])
                elif '_value' in cat:
                    entities['label'].append(label_vals_simplified['ANSWER'])
                else:
                    entities['label'].append(label_vals_simplified['OTHER'])
                entities['cat'].append(cat)
    return entities
    
        
        
           

def label_tokens(annotation, category, bbox):
    label_vals = {'O' : 0, 'B-QUESTION' : 1, 'B-ANSWER' : 2, 'B-HEADER' : 3, 'I-ANSWER' : 4, 'I-QUESTION' : 5, 'I-HEADER' : 6}
    
    annotation_attributes = annotation['attributes']
    #bbox = postprocess_bobx(annotation['bbox'])
    text = annotation_attributes['content']
    tokens, _, _ = split_text_bboxes(bbox, text, category)
    labels = []
    #category_temp = category[:category.rfind('_')]
    for i in range(len(tokens)):
        if i==0:
            #if category_temp in keys_needed:
                #print(f'keys needed {category_temp}')
            if 'key' in category:
                labels.append(label_vals['B-QUESTION'])
            elif 'value' in category:
                labels.append(label_vals['B-ANSWER'])
            else:
                #print(f'keys not needed {category_temp}')
                #print('---')
                labels.append(label_vals['O'])
        else:
            #if category_temp in keys_needed:
            #    print(f'keys needed {category_temp}')
            if 'key' in category:
                labels.append(label_vals['I-QUESTION'])
            elif 'value' in category :
                labels.append(label_vals['I-ANSWER'])
            else:
                #print(f'keys not needed {category_temp}')
                #print('---')
                labels.append(label_vals['O'])
    #print(labels)    
    return labels

def label_input_ids(tokens, bboxes, tokenizer, labels_tokens):

    tokens_input_ids = {}
    labels = []
    for i,token in enumerate(tokens):
        #print(bboxes[1])
        #print(f'len(token) {len(token)}')
        input_ids, _, _ = encode_tokens(tokens=[token], bboxes=[bboxes[i]], tokenizer=tokenizer)
        tokens_input_ids[token] = input_ids
        #print(f'len(input_ids) {len(input_ids)}')
        #print('---')
        token_label = labels_tokens[i]
        labels_tokens_local = [token_label for _ in range(len(input_ids))]
        labels.extend(labels_tokens_local)
    
    return labels, tokens_input_ids
        
        
    

def form_relations(entities, input_ids):
    entity_names_cat = {'entity_names':[], 'cat':[]}
    relations={'head':[], 'tail':[]}
    for i , (start, end) in enumerate(zip(entities['start'], entities['end'])):
        #print(f'{i}, {tokenizer.decode(input_ids[start:end])} : {entities["label"][i]} {entities["cat"][i]}')
        #if entities["label"][i].lower() != 'other':
        entity_names_cat['entity_names'].append(tokenizer.decode(input_ids[start:end]))
        entity_names_cat['cat'].append(entities['cat'][i])
 
    for i, entity in enumerate(entity_names_cat['entity_names']):
        cat = entity_names_cat['cat'][i]
        if '_key' in cat.lower():         
            j = entity_names_cat['cat'].index(f'{cat[:-4:]}_value') if f'{cat[:-4:]}_value' in entity_names_cat['cat'] else None
            if j is not None:
                head = i
                tail = j
                relations['head'].append(head)
                relations['tail'].append(tail)
            
                
            
        
    return entity_names_cat, relations
        
def dump_pickle(file_name:str=None, collection:object=None):
        file_name = os.path.join(os.getcwd(), file_name)
        with open(file_name, 'wb') as f:
            pickle.dump(collection, f)
            
def combine_annotations(image_id:int =None, configs=None, tokenizer=None, model =None, image_dim:dict=None):
    annotations = load_annotation_image(image_id=image_id, configs=configs)
    filtered_annotations = {'image_id':image_id, 'bboxes_tokens':[], 'bboxes':[], 'categories':[], 'text':[], 'labels' :[], 'labels_no_re':[], 'input_ids':[], 'entities':[], 'relations':[], 'input_id_map':{}, 'token_cat_groups':[]}
    for annotation in annotations:
        bbox = postprocess_bobx(annotation['bbox'], image_dim)
        category = load_category(category_id=annotation['category_id'], configs=configs)["name"]
        #category = category if category in keys_needed else 'Others'
        
        annotation_attributes = annotation['attributes']
        if 'type' in annotation_attributes.keys() and category in keys_needed:
            type = annotation_attributes['type']
            filtered_annotations['categories'].append(f'{category}_{type}')
            category = f'{category}_{type}'

        
        text = annotation_attributes['content']
        tokens, bboxes, categories = split_text_bboxes(bbox, text, category)
        token_cat_group = (tokens, categories)
        filtered_annotations['token_cat_groups'].append(token_cat_group)
        labels = label_tokens(annotation, category, bbox)
        filtered_annotations['bboxes_tokens'].extend(bboxes)
        filtered_annotations['text'].extend(tokens)
        filtered_annotations['categories'].extend(categories)
        filtered_annotations['labels'].extend(labels)
        labels_no_re = label_tokens_no_re(annotation, category, bbox, key_classification_no_re)
        filtered_annotations['labels_no_re'].extend(labels_no_re)
    
    tokens, bbox = preprocess_tokens(tokens=filtered_annotations['text'], bboxes=filtered_annotations['bboxes_tokens'])
    tokenizer, model = add_tokens_tokenizer(tokens = tokens, tokenizer = tokenizer, model = model)
    input_ids, bboxes, input_id_map = encode_tokens(tokens=tokens, bboxes=bbox, tokenizer=tokenizer)
    filtered_annotations['bboxes'] = bboxes
    labels, tokens_input_ids_map = label_input_ids(tokens, filtered_annotations['bboxes_tokens'], tokenizer, filtered_annotations['labels'])
    labels_no_re= label_input_ids_no_re(tokens, tokens_input_ids_map, filtered_annotations['labels_no_re'])
    filtered_annotations['labels'] = labels
    filtered_annotations['labels']
    filtered_annotations['input_id_map'] = input_id_map
    filtered_annotations['input_ids'].extend(input_ids)
    filtered_annotations['labels_no_re'] = labels_no_re
    
    #print(input_ids)
    #print(input_id_map)
    
        
    return filtered_annotations

# %%
images_dir = "images"
images_resized_dir = "images_resized"
bbox_dir="bbox"
input_ids_dir = "input_ids"
labels_dir = "labels"
entities_dir = "entities"
relations_dir = "relations"

# %% [markdown]
# ## Impl 2 dataset generation funsd

# %%
from tqdm import tqdm
import random
import shutil

def create_directory_structure(dataset_dir:str, sub_dir:list, overwrite:bool):
    if overwrite and os.path.exists(dataset_dir):
        shutil.rmtree(dataset_dir)
        
    os.mkdir(dataset_dir)
    
    sub_dirs=['train', 'validation']
    for sub_dir in sub_dirs:
        inner_dir =f'{dataset_dir}/{sub_dir}' 
        os.mkdir(inner_dir)
        os.mkdir(f'{inner_dir}/{images_dir}')
        os.mkdir(f'{inner_dir}/{images_resized_dir}')
        os.mkdir(f'{inner_dir}/{bbox_dir}')
        os.mkdir(f'{inner_dir}/{labels_dir}')
        os.mkdir(f'{inner_dir}/{entities_dir}')
        os.mkdir(f'{inner_dir}/{relations_dir}')
        os.mkdir(f'{inner_dir}/{input_ids_dir}')

def get_file_index_map(path:str=None):
        paths = os.listdir(path)
        sorted_paths = sorted(paths, key=lambda x: int(x[x.rindex("_")+1:x.rindex(".")]))
        print(sorted_paths)
        idx_map = {sorted_path[sorted_path.rindex("_")+1:sorted_path.rindex(".")]:sorted_path for sorted_path in sorted_paths}
        #idx_map = {i:paths[i] for i in range(len(paths))}
        return idx_map

def load_dataset_funsd(annotations_configs:dict=None, image_dirs:dict=None, dataset_dir:str= 'dataset_real', tokenizer=None, model=None, train_test_split:float=0.05, 
                       overwrite :bool=True, dataset='all', no_re:bool=None):
    sub_dirs = ['train', 'validation']
    create_directory_structure(dataset_dir, sub_dirs, True)
    configs_list = []
    image_dirs_list = []
    if dataset=='all':
        for key in annotations_configs.keys():
            configs_list.append(annotations_configs[key])
            image_dirs_list.append(image_dirs[key])
    else:
        for sub_dataset in dataset: 
            configs_list.append(annotations_configs[sub_dataset])
            image_dirs_list.append(image_dirs[sub_dataset])
        
    count = 0
    for annotations_config, image_dir in zip(configs_list, image_dirs_list):
        record_count = 0
        with open(annotations_config) as f:
            configs = json.load(f)
        #label_vals = {'O' : 0, 'B-QUESTION' : 1, 'B-ANSWER' : 2, 'B-HEADER' : 3, 'I-ANSWER' : 4, 'I-QUESTION' : 5, 'I-HEADER' : 6}
        #label_vals_reversed = {val:key for (key,val) in label_vals.items()} 
        image_ids = []    
        indices_to_keep = []
        print('populating valid image indices')
        for i,image_obj in enumerate(configs['images']):
            if i>=0:
                image_ids.append(image_obj['id'])
            
                image_path = f'{image_dir}/{image_obj["file_name"]}'
                img_height = image_obj["height"]
                img_width = image_obj["width"]
        
                combined_annotations = combine_annotations(image_id=image_obj['id'], configs=configs, tokenizer=tokenizer, model=model, image_dim={'width':img_width, 'height':img_height})
                print(f'image_obj["file_name"] {image_obj["file_name"]} {count + i}')
                entities = form_entities(combined_annotations['token_cat_groups'], tokenizer, combined_annotations['input_ids'], combined_annotations['input_id_map'])
                combined_annotations['entities'] = entities
                entity_names_cat, relations = form_relations(entities, combined_annotations['input_ids'])
                if len(relations['head']) > 0:
                    #indices_to_keep.append(i)
                    #print(f'{i} {image_obj["file_name"]}')
                    #for i in range(len(relations['head'])):
                    #    print(f'question : {entity_names_cat["entity_names"][relations["head"][i]]}, Answer :  {entity_names_cat["entity_names"][relations["tail"][i]]}, start: {relations["head"][i]}, end: {relations["tail"][i]}')
                    #print('------------')
                    image = cv2.imread(image_path)
                    image_resized = cv2.resize(image, (224,224))
                    bbox = combined_annotations['bboxes']
                    input_ids = combined_annotations['input_ids']
                    labels = combined_annotations['labels_no_re'] if no_re else combined_annotations['labels']
                
                    cv2.imwrite(f'{dataset_dir}/train/{images_dir}/image_{i+count}.jpeg', image)
                    cv2.imwrite(f'{dataset_dir}/train/{images_resized_dir}/image_resized_{i+count}.jpeg', image_resized)
                    bbox_path = f'{dataset_dir}/train/{bbox_dir}/bbox_{i+count}.p'
                    labels_path = f'{dataset_dir}/train/{labels_dir}/labels_{i+count}.p'
                    entities_path = f'{dataset_dir}/train/{entities_dir}/entities_{i+count}.p'
                    input_ids_path = f'{dataset_dir}/train/{input_ids_dir}/input_ids_{i+count}.p'
                    realations_path = f'{dataset_dir}/train/{relations_dir}/relations_{i+count}.p'
            
                    dump_pickle(file_name=bbox_path, collection=bbox)
                    dump_pickle(file_name=labels_path, collection=labels)
                    dump_pickle(file_name=entities_path, collection=entities)
                    dump_pickle(file_name=input_ids_path, collection=input_ids)
                    dump_pickle(file_name=realations_path, collection=relations)
                    record_count+=1
        count+=record_count

# %%
def split_data(train_test_split:float=None, dataset_dir:str=None):
    #file_indices = [i for i in range(len(os.listdir(f'{dataset_dir}/train/images')))]
    
    file_indices = [int(path[path.rindex("_")+1 : path.rindex(".")]) for path in os.listdir(f'{dataset_dir}/train/images')]
    validation_percentage = int(train_test_split * len(file_indices))
    validation_indices = random.choices(file_indices, k= validation_percentage)
    validation_indices = list(set(validation_indices))
    
    idx_map_image = get_file_index_map(path = f'{dataset_dir}/train/images')
    idx_map_image_resized = get_file_index_map(path = f'{dataset_dir}/train/images_resized')
    idx_map_bbox = get_file_index_map(path = f'{dataset_dir}/train/bbox')
    idx_map_labels = get_file_index_map(path = f'{dataset_dir}/train/labels')
    idx_map_entities = get_file_index_map(path = f'{dataset_dir}/train/entities')
    idx_map_realations = get_file_index_map(path = f'{dataset_dir}/train/relations')
    idx_map_input_ids = get_file_index_map(path = f'{dataset_dir}/train/input_ids')
    
    #print(validation_indices)
    #print(idx_map_image)
    
    for i in validation_indices:
        i = str(i)    
        shutil.move(f'{dataset_dir}/train/images/{idx_map_image[i]}', f'{dataset_dir}/validation/images/{idx_map_image[i]}')
        shutil.move(f'{dataset_dir}/train/images_resized/{idx_map_image_resized[i]}', f'{dataset_dir}/validation/images_resized/{idx_map_image_resized[i]}')
        shutil.move(f'{dataset_dir}/train/bbox/{idx_map_bbox[i]}', f'{dataset_dir}/validation/bbox/{idx_map_bbox[i]}')
        shutil.move(f'{dataset_dir}/train/input_ids/{idx_map_input_ids[i]}', f'{dataset_dir}/validation/input_ids/{idx_map_input_ids[i]}')
        shutil.move(f'{dataset_dir}/train/labels/{idx_map_labels[i]}', f'{dataset_dir}/validation/labels/{idx_map_labels[i]}')
        shutil.move(f'{dataset_dir}/train/entities/{idx_map_entities[i]}', f'{dataset_dir}/validation/entities/{idx_map_entities[i]}')
        shutil.move(f'{dataset_dir}/train/relations/{idx_map_realations[i]}', f'{dataset_dir}/validation/relations/{idx_map_realations[i]}')
    #print('---')
    #print(len(file_list))
    #print(len(list(set(file_list))))

# %%
#dataset=['schindler_annotations', 'kone_annotations', 'dekra_annotations']
dataset=['schindler_annotations', 'kone_annotations', 'dekra_annotations', 'TUV_nord_annotations']

# %%
root_dir = 'all_annotations/'
annotations_dirs = {dir:f'{root_dir}/{dir}/annotations/instances_default.json' for dir in os.listdir(root_dir)}
image_dirs = {dir:f'{root_dir}/{dir}/images' for dir in os.listdir(root_dir)}


load_dataset_funsd(annotations_configs=annotations_dirs,image_dirs=image_dirs, tokenizer=tokenizer, model=model, dataset=dataset, no_re=True, dataset_dir='dataset_real_no_re')
# Out:
# populating valid image indices
# image_obj["file_name"] template_4_schindler/2013-03-04 Wartungsprotokoll, Aufzugsanlagen 88938, Schindler (7006)/page_0.jpg 0
# image_obj["file_name"] template_4_schindler/2013-03-04 Wartungsprotokoll, Aufzugsanlagen 88939, Schindler (7006)/page_0.jpg 1
# image_obj["file_name"] template_4_schindler/2013-04-19 Wartungsprotokoll,  Aufzugsanlagen 88939, Schindler (7006)/page_0.jpg 2
# image_obj["file_name"] template_4_schindler/2013-04-19 Wartungsprotokoll, Aufzugsanlagen 88938, Schindler (7006)/page_0.jpg 3
# image_obj["file_name"] template_4_schindler/2013-08-09 Wartungsprotokoll, Aufzugsanlagen 88939, Schindler (7006)/page_0.jpg 4
# image_obj["file_name"] template_4_schindler/2013-08-12 Wartungsprotokoll, Aufzugsanlagen 88938, Schindler (7006)/page_0.jpg 5
# image_obj["file_name"] template_4_schindler/2015-01-07_Aufzugswartung_88938_Schindler_(7006)/page_0.jpg 6
# image_obj["file_name"] template_4_schindler/2015-01-07_Aufzugswartung_88939_Schindler_(7006)/page_0.jpg 7
# image_obj["file_name"] template_4_schindler/2015-03-05_Aufzugswartung_88938_Schindler_(7006)/page_0.jpg 8
# image_obj["file_name"] template_4_schindler/2015-03-05_Aufzugswartung_88939_Schindle_(7006)/page_0.jpg 9
# image_obj["file_name"] template_4_schindler/2015-04-08 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 10
# image_obj["file_name"] template_4_schindler/2015-04-09 Wartungsbericht, Aufzug 47NG9683, Firma Schindler, WE 2040/page_0.jpg 11
# image_obj["file_name"] template_4_schindler/2015-06-01_Aufzugswartung_88938_Schindler_(7006)/page_0.jpg 12
# image_obj["file_name"] template_4_schindler/2015-06-01_Aufzugswartung_88939_Schindler_(7006)/page_0.jpg 13
# image_obj["file_name"] template_4_schindler/2015-07-15_Aufzugswartung_88938_Schindler_(7006)/page_0.jpg 14
# image_obj["file_name"] template_4_schindler/2015-07-21 Wartungsbericht, Aufzug 47NG9683, Firma Schindler, WE 2040/page_0.jpg 15
# image_obj["file_name"] template_4_schindler/2015-07-22_Aufzugswartung_88939_Schindler_(7006)/page_0.jpg 16
# image_obj["file_name"] template_4_schindler/2015-08-06 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 17
# image_obj["file_name"] template_4_schindler/2015-09-28_Aufzugswartung_88938_Schindler_(7006)/page_0.jpg 18
# image_obj["file_name"] template_4_schindler/2015-09-28_Aufzugswartung_88939_Schindler_(7006)/page_0.jpg 19
# image_obj["file_name"] template_4_schindler/2015-11-11 Wartungsbericht, Aufzug 47NG6983, Firma Schindler, WE 2040/page_0.jpg 20
# image_obj["file_name"] template_4_schindler/2015-11-13 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 21
# image_obj["file_name"] template_4_schindler/2015-11-16_Aufzugswartung_88938_Schindler_(7006)/page_0.jpg 22
# image_obj["file_name"] template_4_schindler/2015-11-16_Aufzugswartung_88939_Schindler_(7006)/page_0.jpg 23
# image_obj["file_name"] template_4_schindler/2015-12-17 Wartungsbericht, Aufzug 47NG9683, Firma Schindler, WE 2040/page_0.jpg 24
# image_obj["file_name"] template_4_schindler/2015-12-18 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 25
# image_obj["file_name"] template_4_schindler/2016-01-06_Wartung Aufzug 18000649311_Schindler(9507)/page_0.jpg 26
# image_obj["file_name"] template_4_schindler/2016-01-11_Aufzugswartung_88938_Schindler_(7006)/page_0.jpg 27
# image_obj["file_name"] template_4_schindler/2016-01-11_Aufzugswartung_88939_Schindler_(7006)/page_0.jpg 28
# image_obj["file_name"] template_4_schindler/2016-01-22 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 29
# image_obj["file_name"] template_4_schindler/2016-02-11_Wartung Aufzüge 18000649310-11_Schindler (9507)/page_0.jpg 30
# image_obj["file_name"] template_4_schindler/2016-02-11_Wartung Aufzüge 18000649310-11_Schindler (9507)/page_1.jpg 31
# image_obj["file_name"] template_4_schindler/2016-03-09 Wartungsnachweis Anl. 06026, Schindler (1267)/page_0.jpg 32
# image_obj["file_name"] template_4_schindler/2016-03-09 Wartungsnachweis Anl. 06028, Schindler (1267)/page_0.jpg 33
# image_obj["file_name"] template_4_schindler/2016-03-09 Wartungsnachweis Anl. 06029, Schindler (1267)/page_0.jpg 34
# image_obj["file_name"] template_4_schindler/2016-03-23 Wartungsbericht, Aufzug 47NG6983, Firma Schindler, WE 2040/page_0.jpg 35
# image_obj["file_name"] template_4_schindler/2016-03-23 Wartungsbericht, Aufzug 47NG9684, Firma Schindler, WE 2040/page_0.jpg 36
# image_obj["file_name"] template_4_schindler/2016-03-23 Wartungsprotokoll, Aufzug, Fa. Schindler (9507)/page_0.jpg 37
# image_obj["file_name"] template_4_schindler/2016-03-23_Aufzugswartung_88938_Schindler_(7006)/page_0.jpg 38
# image_obj["file_name"] template_4_schindler/2016-03-23_Aufzugswartung_88939_Schindler_(7006)/page_0.jpg 39
# image_obj["file_name"] template_4_schindler/2016-03-31 Wartungnachweis Anl. 06025, Schindler (1267)/page_0.jpg 40
# image_obj["file_name"] template_4_schindler/2016-03-31 Wartungsnachweis Anl. 06024, Schindler (1267)/page_0.jpg 41
# image_obj["file_name"] template_4_schindler/2016-03-31 Wartungsnachweis Anl. 06027, Schindler (1267)/page_0.jpg 42
# image_obj["file_name"] template_4_schindler/2016-04-03 Wartungsnachweis Anl. 06029, Schindler (1267)/page_0.jpg 43
# image_obj["file_name"] template_4_schindler/2016-04-19 Wartungsprotokoll Aufzug  Fa. Schindler (9507)/page_0.jpg 44
# image_obj["file_name"] template_4_schindler/2016-05-16 Wartungsnachweis Anl. 06028, Schindler (1267)/page_0.jpg 45
# image_obj["file_name"] template_4_schindler/2016-05-17 Wartungsnachweis Anl 06024, Schindler (1267)/page_0.jpg 46
# image_obj["file_name"] template_4_schindler/2016-05-18 Wartungsprotokoll, Aufzug, Schindler  (9507)/page_0.jpg 47
# image_obj["file_name"] template_4_schindler/2016-06-20 Wartungsnachweis Anl 06025, Schindler (1267)/page_0.jpg 48
# image_obj["file_name"] template_4_schindler/2016-06-20 Wartungsnachweis Anl. 06026, Schindler (1267)/page_0.jpg 49
# image_obj["file_name"] template_4_schindler/2016-06-20 Wartungsnachweis Anl. 06027, Schindler (1267)/page_0.jpg 50
# image_obj["file_name"] template_4_schindler/2016-06-21 Wartungsbericht, Aufzug 47NG9683, Firma Schindler, WE 2040/page_0.jpg 51
# image_obj["file_name"] template_4_schindler/2016-06-21 Wartungsbericht, Aufzug 47NG9684, Firma Schindler, WE 2040/page_0.jpg 52
# image_obj["file_name"] template_4_schindler/2016-07-08 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 53
# image_obj["file_name"] template_4_schindler/2016-09-19 Wartungsnachweis Anl. 06026, Schindler (1267)/page_0.jpg 54
# image_obj["file_name"] template_4_schindler/2016-09-19 Wartungsnachweis Anl. 06028, Schindler (1267)/page_0.jpg 55
# image_obj["file_name"] template_4_schindler/2016-09-19Wartungsnachweis Anl. 06027, Schindler (1267)/page_0.jpg 56
# image_obj["file_name"] template_4_schindler/2016-09-20 Wartungsnachweis Anl. 06024, Schindler (1267)/page_0.jpg 57
# image_obj["file_name"] template_4_schindler/2016-09-20 Wartungsnachweis Anl. 06029 , Schindler (1267)/page_0.jpg 58
# image_obj["file_name"] template_4_schindler/2016-09-21 Wartungsnachweis Anl. 06025, Schindler (1267)/page_0.jpg 59
# image_obj["file_name"] template_4_schindler/2016-10-28 Wartungsbericht, Aufzug 47NG9684, Firma Schindler, WE 2040/page_0.jpg 60
# image_obj["file_name"] template_4_schindler/2016-10-28 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 61
# image_obj["file_name"] template_4_schindler/2016-11-18 Wartungsnachweis Anl. 06024, Schindler (1267)/page_0.jpg 62
# image_obj["file_name"] template_4_schindler/2016-11-18 Wartungsnachweis Anl. 06026, Schindler (1267)/page_0.jpg 63
# image_obj["file_name"] template_4_schindler/2016-11-18 Wartungsnachweis Anl. 06028, Schindler (1267)/page_0.jpg 64
# image_obj["file_name"] template_4_schindler/2016-11-18 Wartungsnachweis Anl. 06029, Schindler (1267)/page_0.jpg 65
# image_obj["file_name"] template_4_schindler/2016-11-23 Wartungsnachweis Anl. 06025, Schindler (1267)/page_0.jpg 66
# image_obj["file_name"] template_4_schindler/2016-11-23 Wartungsnachweis Anl. 06027, Schindler (1267)/page_0.jpg 67
# image_obj["file_name"] template_4_schindler/2016-12-27 Wartungsbericht, Aufzug 47NG9683, Firma Schindler, WE 2040/page_0.jpg 68
# image_obj["file_name"] template_4_schindler/2016-12-27 Wartungsbericht, Aufzug 47NG9684, Firma Schindler, WE 2040/page_0.jpg 69
# image_obj["file_name"] template_4_schindler/2016-12-27 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 70
# image_obj["file_name"] template_4_schindler/2017-01-31 Wartungsbericht, Aufzug 47NG9684, Firma Schindler, WE 2040/page_0.jpg 71
# image_obj["file_name"] template_4_schindler/2017-03-10 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 72
# image_obj["file_name"] template_4_schindler/2017-04-21 WP 6025, Schindler (1267)/page_0.jpg 73
# image_obj["file_name"] template_4_schindler/2017-06-20 WP 6025, Schindler (1267)/page_0.jpg 74
# image_obj["file_name"] template_4_schindler/2017-06-24 Wartungsbericht, Aufzug 47NG9684, Firma Schindler, WE 2040/page_0.jpg 75
# image_obj["file_name"] template_4_schindler/2017-06-24 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 76
# image_obj["file_name"] template_4_schindler/2017-06-27 WP 06024, Schindler (1267)/page_0.jpg 77
# image_obj["file_name"] template_4_schindler/2017-07-11 Wartung FP 6027, Schindler (1267)/page_0.jpg 78
# image_obj["file_name"] template_4_schindler/2017-07-14 WP 6026, Schindler (1267)/page_0.jpg 79
# image_obj["file_name"] template_4_schindler/2017-07-19 WP 6028, Schindler (1267)/page_0.jpg 80
# image_obj["file_name"] template_4_schindler/2017-08-29 WP 06027, Schindler (1267)/page_0.jpg 81
# image_obj["file_name"] template_4_schindler/2017-08-31 WP 06028, Schindler (1267)/page_0.jpg 82
# image_obj["file_name"] template_4_schindler/2017-09-15 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 83
# image_obj["file_name"] template_4_schindler/2017-09-18 Wartungsbericht, Aufzug 47NG9684, Firma Schindler, WE 2040/page_0.jpg 84
# image_obj["file_name"] template_4_schindler/2017-10-30 WP 06024, Schindler (1267)/page_0.jpg 85
# image_obj["file_name"] template_4_schindler/2017-11-02 WP 06026, Schindler (1267)/page_0.jpg 86
# image_obj["file_name"] template_4_schindler/2017-11-06 WP 06028, Schindler (1267)/page_0.jpg 87
# image_obj["file_name"] template_4_schindler/2017-12-14 WP 06026, Schindler (1267)/page_0.jpg 88
# image_obj["file_name"] template_4_schindler/2017-12-14 WP 06027, Schindler (1267)/page_0.jpg 89
# image_obj["file_name"] template_4_schindler/2017-12-14 WP 6025, Schindler (1267)/page_0.jpg 90
# image_obj["file_name"] template_4_schindler/2017-14-12 WP06024, Schindler (1267)/page_0.jpg 91
# image_obj["file_name"] template_4_schindler/2018-02-09 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 92
# image_obj["file_name"] template_4_schindler/2018-04-13 Wartungsbericht, Aufzug 47NG9683, Firma Schindler, WE 2040/page_0.jpg 93
# image_obj["file_name"] template_4_schindler/2018-04-13 Wartungsbericht, Aufzug 47NG9684, Firma Schindler, WE 2040/page_0.jpg 94
# image_obj["file_name"] template_4_schindler/2018-05-03 WP 06026, Sodexo (1267)/page_0.jpg 95
# image_obj["file_name"] template_4_schindler/2018-08-03 WP 06026, Schindler (1267)/page_0.jpg 96
# image_obj["file_name"] template_4_schindler/2018-08-23 Wartungsbericht, Aufzug 47NG9683, Firma Schindler, WE 2040/page_0.jpg 97
# image_obj["file_name"] template_4_schindler/2018-08-23 Wartungsbericht, Aufzug 47NG9684, Firma Schindler, WE 2040/page_0.jpg 98
# image_obj["file_name"] template_4_schindler/2018-08-24 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 99
# image_obj["file_name"] template_4_schindler/2018-12-07 Wartungsbericht, Aufzug 47NG9683, Firma Schindler, WE 2040/page_0.jpg 100
# image_obj["file_name"] template_4_schindler/2018-12-07 Wartungsbericht, Aufzug 47NG9684, Firma Schindler, WE 2040/page_0.jpg 101
# image_obj["file_name"] template_4_schindler/2018-12-07 Wartungsbericht, Aufzug 47NG9685, Firma Schindler, WE 2040/page_0.jpg 102
# populating valid image indices
# image_obj["file_name"] template_5_kone/2019-05-10 WP 6024, KONE (1267)/page_0.jpg 99
# image_obj["file_name"] template_5_kone/2019-05-13 WP 6026, KONE (1267)/page_0.jpg 100
# image_obj["file_name"] template_5_kone/2019-07-08 WP6026, KONE (1267)/page_0.jpg 101
# image_obj["file_name"] template_5_kone/2019-07-11 WP6024, KONE (1267)/page_0.jpg 102
# image_obj["file_name"] template_5_kone/2019-09-18 WP6026; KONE (1267)/page_0.jpg 103
# image_obj["file_name"] template_5_kone/2019-11-21 WP6026, KONE (1267)/page_0.jpg 104
# image_obj["file_name"] template_5_kone/2019-11-22 WP6024 Teil2, KONE (1267)/page_0.jpg 105
# image_obj["file_name"] template_5_kone/2019-11-22 WP6024, kone (1267)/page_0.jpg 106
# image_obj["file_name"] template_5_kone/2020-01-16 WP 6024, Kone (1267)/page_0.jpg 107
# image_obj["file_name"] template_5_kone/2020-01-16 WP 6026, Kone (1267)/page_0.jpg 108
# image_obj["file_name"] template_5_kone/2020-01-21 Instandsetzungsnachweis, Aufzug 97280 Akku, KONE (7029)/page_0.jpg 109
# image_obj["file_name"] template_5_kone/2020-02-19 Wartungsnachweis, Aufzug 97279, Q1, KONE (7029)/page_0.jpg 110
# image_obj["file_name"] template_5_kone/2020-02-20 WP 6024, Kone (1267)/page_0.jpg 111
# image_obj["file_name"] template_5_kone/2020-02-24 Wartungsanchweis Aufzug 10816199 Q1 Kone (5003)/page_0.jpg 112
# image_obj["file_name"] template_5_kone/2020-02-25 WP6026, Kone (1267)/page_0.jpg 113
# image_obj["file_name"] template_5_kone/2020-03-19 Wartungsnachweis, Aufzug 97280, Q1, KONE (7029)/page_0.jpg 114
# image_obj["file_name"] template_5_kone/2020-05-06 WP 6024, Kone (1267)/page_0.jpg 115
# image_obj["file_name"] template_5_kone/2020-05-06 WP6026, Kone (1267)/page_0.jpg 116
# image_obj["file_name"] template_5_kone/2020-05-18 Wartungsnachweis, Aufzug 97280, Q2, KONE (7029)/page_0.jpg 117
# image_obj["file_name"] template_5_kone/2020-05-28 Wartungsnachweis, Aufzug 97279, Q2, KONE (7029)/page_0.jpg 118
# image_obj["file_name"] template_5_kone/2020-07-15 WP 6024, Kone (1267)/page_0.jpg 119
# image_obj["file_name"] template_5_kone/2020-07-20 WP6026, Kone (1267)/page_0.jpg 120
# image_obj["file_name"] template_5_kone/2020-07-30 Wartungsanchweis Aufzug 10816199 Q2 Kone (5003)/page_0.jpg 121
# image_obj["file_name"] template_5_kone/2020-07-30 Wartungsanchweis Aufzug 10816200 Q2 Kone (5003)/page_0.jpg 122
# image_obj["file_name"] template_5_kone/2020-09-03 Wartungsnachweis, Aufzug 97279, Q3, KONE (7029)/page_0.jpg 123
# image_obj["file_name"] template_5_kone/2020-09-18 Wartungsanchweis Aufzug 10816199 Q3 Kone (5003)/page_0.jpg 124
# image_obj["file_name"] template_5_kone/2020-09-18 Wartungsanchweis Aufzug 10816200 Q3 Kone (5003)/page_0.jpg 125
# image_obj["file_name"] template_5_kone/2020-09-22 WP6026, Kone (1267)/page_0.jpg 126
# image_obj["file_name"] template_5_kone/2020-09-24 WP 6024, Kone (1267)/page_0.jpg 127
# image_obj["file_name"] template_5_kone/2020-11-04 Wartungsnachweis, Aufzug 97279, Q4, KONE (7029)/page_0.jpg 128
# image_obj["file_name"] template_5_kone/2020-11-04 Wartungsnachweis, Aufzug 97280, Q4, KONE (7029)/page_0.jpg 129
# image_obj["file_name"] template_5_kone/2020-11-10 WP 6024, Kone (1267)/page_0.jpg 130
# image_obj["file_name"] template_5_kone/2020-11-10 WP6026, Kone (1267)/page_0.jpg 131
# image_obj["file_name"] template_5_kone/2020-11-17 Wartungsanchweis Aufzug 10816199 Q4 Kone (5003)/page_0.jpg 132
# image_obj["file_name"] template_5_kone/2020-11-17 Wartungsanchweis Aufzug 10816200 Q4 Kone (5003)/page_0.jpg 133
# image_obj["file_name"] template_5_kone/2021-01-13 WP 6024, Kone (1267)/page_0.jpg 134
# image_obj["file_name"] template_5_kone/2021-01-13 WP6026, Kone (1267)/page_0.jpg 135
# image_obj["file_name"] template_5_kone/2021-03-04 WP 6024, Kone (1267)/page_0.jpg 136
# image_obj["file_name"] template_5_kone/2021-03-04 WP6026, Kone (1267)/page_0.jpg 137
# image_obj["file_name"] template_5_kone/2021-05-12 Wartungsanchweis Aufzug 10816199 Q2 Kone (5003)/page_0.jpg 138
# image_obj["file_name"] template_5_kone/2021-05-12 Wartungsanchweis Aufzug 10816200 Q2 Kone (5003)/page_0.jpg 139
# image_obj["file_name"] template_5_kone/2021-05-18 WP 6024, Kone (1267)/page_0.jpg 140
# image_obj["file_name"] template_5_kone/2021-05-18 WP6026, Kone (1267)/page_0.jpg 141
# image_obj["file_name"] template_5_kone/2021-07-07 WP 6024, Kone (1267)/page_0.jpg 142
# image_obj["file_name"] template_5_kone/2021-07-07 WP6026, Kone (1267)/page_0.jpg 143
# image_obj["file_name"] template_5_kone/2021-07-07 WP6026, Kone (1267)/page_1.jpg 144
# image_obj["file_name"] template_5_kone/2021-09-03 Wartungsanchweis Aufzug 10816199 Q3 Kone (5003)/page_0.jpg 145
# image_obj["file_name"] template_5_kone/2021-09-03 Wartungsanchweis Aufzug 10816200 Q3 Kone (5003)/page_0.jpg 146
# image_obj["file_name"] template_5_kone/2021-09-27 WP 6024, Kone (1267)/page_0.jpg 147
# image_obj["file_name"] template_5_kone/2021-09-27 WP6026, Kone (1267)/page_0.jpg 148
# image_obj["file_name"] template_5_kone/2021-11-01 WP 6024 Kone (1267)/page_0.jpg 149
# image_obj["file_name"] template_5_kone/2021-11-05 WP6026, Kone (1267)/page_0.jpg 150
# image_obj["file_name"] template_5_kone/2021-12-22 Wartungsanchweis Aufzug 10816200 Q4 Kone (5003)/page_0.jpg 151
# image_obj["file_name"] template_5_kone/2022-01-03 Wartungsnachweis Aufzug 302096, Kone (8110)/page_0.jpg 152
# image_obj["file_name"] template_5_kone/2022-01-03 Wartungsnachweis Aufzug 302098, Kone (8110)/page_0.jpg 153
# image_obj["file_name"] template_5_kone/2022-01-03 Wartungsnachweis Aufzug 302099, Kone (8110)/page_0.jpg 154
# image_obj["file_name"] template_5_kone/2022-01-03 Wartungsnachweis Aufzug 302100, Kone (8110)/page_0.jpg 155
# image_obj["file_name"] template_5_kone/2022-01-03 Wartungsnachweis Aufzug 302101, Kone (8110)/page_0.jpg 156
# image_obj["file_name"] template_5_kone/2022-01-11 WP6026, Kone (1267)/page_0.jpg 157
# image_obj["file_name"] template_5_kone/2022-01-14 WP 6024, Kone (1267)/page_0.jpg 158
# image_obj["file_name"] template_5_kone/2022-01-18_Wartungsnachweis Aufzug 1393, Kone (G016) (1)/page_0.jpg 159
# image_obj["file_name"] template_5_kone/2022-01-18_Wartungsnachweis Aufzug 1393, Kone (G016)/page_0.jpg 160
# image_obj["file_name"] template_5_kone/2022-01-20_Wartungsnachweis Aufzug 2683, Kone (G016) (1)/page_0.jpg 161
# image_obj["file_name"] template_5_kone/2022-01-20_Wartungsnachweis Aufzug 2683, Kone (G016)/page_0.jpg 162
# image_obj["file_name"] template_5_kone/2022-01-21 Wartungsnachweis Aufzug 814, Kone (9501)/page_0.jpg 163
# image_obj["file_name"] template_5_kone/2022-01-22 Wartungsnachweis Aufzug 815, Kone (9501)/page_0.jpg 164
# image_obj["file_name"] template_5_kone/2022-02-23 Wartungsanchweis Aufzug 10816199 Q1 Kone (5003)/page_0.jpg 165
# image_obj["file_name"] template_5_kone/2022-02-23 Wartungsanchweis Aufzug 10816200 Q1 Kone (5003)/page_0.jpg 166
# image_obj["file_name"] template_5_kone/2022-02-23_Übergabeprotokoll Aufzug 2683, Kone (G016)/page_0.jpg 167
# image_obj["file_name"] template_5_kone/2022-02-24_Reparaturnachweis Aufzug 2683, Kone (G016)/page_0.jpg 168
# image_obj["file_name"] template_5_kone/2022-02-24_Wartungsnachweis Aufzug 2683, Kone (G016)/page_0.jpg 169
# image_obj["file_name"] template_5_kone/2022-03-14 Wartungsanchweis, Aufzüge Q1, KONE (7029)/page_0.jpg 170
# image_obj["file_name"] template_5_kone/2022-03-14 Wartungsanchweis, Aufzüge Q1, KONE (7029)/page_1.jpg 171
# image_obj["file_name"] template_5_kone/2022-03-18 WP 6024, Kone (1267)/page_0.jpg 172
# image_obj["file_name"] template_5_kone/2022-03-18 WP6026, Kone (1267)/page_0.jpg 173
# image_obj["file_name"] template_5_kone/2022-03-21_ZÜS Begleitung Aufzug 2683, Kone (G016)/page_0.jpg 174
# image_obj["file_name"] template_5_kone/2022-03-30_Wartungsnachweis Aufzug 302096, Kone (8110)/page_0.jpg 175
# image_obj["file_name"] template_5_kone/2022-03-30_Wartungsnachweis Aufzug 302097, Kone (8110)/page_0.jpg 176
# image_obj["file_name"] template_5_kone/2022-03-30_Wartungsnachweis Aufzug 302098, Kone (8110)/page_0.jpg 177
# image_obj["file_name"] template_5_kone/2022-03-30_Wartungsnachweis Aufzug 302099, Kone (8110)/page_0.jpg 178
# image_obj["file_name"] template_5_kone/2022-03-30_Wartungsnachweis Aufzug 302100, Kone (8110)/page_0.jpg 179
# image_obj["file_name"] template_5_kone/2022-03-30_Wartungsnachweis Aufzug 302101, Kone (8110)/page_0.jpg 180
# image_obj["file_name"] template_5_kone/2022-04-13_Wartungsnachweis Aufzug 0815, Kone (9501)/page_0.jpg 181
# image_obj["file_name"] template_5_kone/2022-04-13_Wartungsnachweis Aufzug 1100815, Kone (9501)/page_0.jpg 182
# image_obj["file_name"] template_5_kone/2022-04-13_Wartungsnachweis Aufzug 1393, Kone (G016)/page_0.jpg 183
# image_obj["file_name"] template_5_kone/2022-04-13_Wartungsnachweis Aufzug 2683, Kone (G016)/page_0.jpg 184
# image_obj["file_name"] template_5_kone/2022-04-13_Wartungsnachweis Aufzug 814, Kone (9501)/page_0.jpg 185
# image_obj["file_name"] template_5_kone/2022-04-14_Reparaturnachweis Aufzug 2683, Kone (G016)/page_0.jpg 186
# image_obj["file_name"] template_5_kone/2022-04-14_Wartungsnachweis Aufzug 1393, Kone (G016)/page_0.jpg 187
# image_obj["file_name"] template_5_kone/2022-04-14_Wartungsnachweis Aufzug 2683, Kone (G016)/page_0.jpg 188
# image_obj["file_name"] template_5_kone/2022-05-19 WP 6024, Kone (1267)/page_0.jpg 189
# image_obj["file_name"] template_5_kone/2022-05-19 WP6026, Kone (1267)/page_0.jpg 190
# image_obj["file_name"] template_5_kone/2022-05-20 Wartungsanchweis Aufzug 10816199 Q2 Kone (5003)/page_0.jpg 191
# image_obj["file_name"] template_5_kone/2022-05-20 Wartungsanchweis Aufzug 10816199 Q2 Kone (5003)/page_1.jpg 192
# image_obj["file_name"] template_5_kone/2022-05-20 Wartungsanchweis Aufzug 10816200 Q2 Kone (5003)/page_0.jpg 193
# image_obj["file_name"] template_5_kone/2022-05-20 Wartungsanchweis Aufzug 10816200 Q2 Kone (5003)/page_1.jpg 194
# image_obj["file_name"] template_5_kone/2022-05-26 Wartungsnachweis, Aufzüge Q2, KONE (7029)/page_0.jpg 195
# image_obj["file_name"] template_5_kone/2022-05-26 Wartungsnachweis, Aufzüge Q2, KONE (7029)/page_1.jpg 196
# image_obj["file_name"] template_5_kone/2022-07-06 WP 6024, Kone (1267)/page_0.jpg 197
# image_obj["file_name"] template_5_kone/2022-07-06 WP 6024, Kone (1267)/page_1.jpg 198
# image_obj["file_name"] template_5_kone/2022-07-08 WP 6026, Kone (1267)/page_0.jpg 199
# image_obj["file_name"] template_5_kone/2022-07-08 WP 6026, Kone (1267)/page_1.jpg 200
# image_obj["file_name"] template_5_kone/2022-07-13_Wartung Aufzug 1393, Kone (G016)/page_0.jpg 201
# image_obj["file_name"] template_5_kone/2022-07-13_Wartung Aufzug 2683, Kone (G016)/page_0.jpg 202
# image_obj["file_name"] template_5_kone/2022-07-28_Wartungsnachweis Aufzug 814, Kone (9501)/page_0.jpg 203
# image_obj["file_name"] template_5_kone/2022-07-28_Wartungsnachweis Aufzug 815, Kone (9501)/page_0.jpg 204
# image_obj["file_name"] template_5_kone/2022-09-28 Wartungsnachweis, Aufzüge Q3, KONE (7029)/page_0.jpg 205
# image_obj["file_name"] template_5_kone/2022-09-28 Wartungsnachweis, Aufzüge Q3, KONE (7029)/page_1.jpg 206
# image_obj["file_name"] template_5_kone/2022-09-28 Wartungsnachweis, Aufzüge, KONE (7029)/page_0.jpg 207
# image_obj["file_name"] template_5_kone/2022-09-28 Wartungsnachweis, Aufzüge, KONE (7029)/page_1.jpg 208
# image_obj["file_name"] template_5_kone/2022-10-10_Wartungsnachweis Aufzug 0814, Kone (9501)/page_0.jpg 209
# image_obj["file_name"] template_5_kone/2022-10-10_Wartungsnachweis Aufzug 0815, Kone (9501)/page_0.jpg 210
# image_obj["file_name"] template_5_kone/2022-12-01 Wartungsnachweis, Aufzüge Q4, KONE (7029)/page_0.jpg 211
# image_obj["file_name"] template_5_kone/2022-12-01 Wartungsnachweis, Aufzüge Q4, KONE (7029)/page_1.jpg 212
# image_obj["file_name"] template_5_kone/2023-05-12 WP 6026, Kone (1267)/page_0.jpg 213
# populating valid image indices
# image_obj["file_name"] template_2_dekra/2017-03-15 Prüfbericht, Hauptprüfung Aufzugsanlage 47NAL566, Dekra (9511)/page_0.jpg 203
# image_obj["file_name"] template_2_dekra/2017-03-15 Prüfbericht, Hauptprüfung Aufzugsanlage 47NAL567, Dekra (9511)/page_0.jpg 204
# image_obj["file_name"] template_2_dekra/2017-03-15 Prüfbericht, Hauptprüfung Aufzugsanlage 47NAL568, Dekra (9511)/page_0.jpg 205
# image_obj["file_name"] template_2_dekra/2017-03-15 Prüfbericht, Hauptprüfung Aufzugsanlage 47NAL569, Dekra (9511)/page_0.jpg 206
# image_obj["file_name"] template_2_dekra/2017-03-15 Prüfbericht, Hauptprüfung Aufzugsanlage 47NAL570, Dekra (9511)/page_0.jpg 207
# image_obj["file_name"] template_2_dekra/2017-03-15 Prüfbericht, Hauptprüfung Aufzugsanlage 47NAL571, Dekra (9511)/page_0.jpg 208
# image_obj["file_name"] template_2_dekra/2017-03-15 Prüfbericht, Hauptprüfung Aufzugsanlage 47NAL572, Dekra (9511)/page_0.jpg 209
# image_obj["file_name"] template_2_dekra/2017-03-15 Prüfbericht, Hauptprüfung Aufzugsanlage 47NAL573, Dekra (9511)/page_0.jpg 210
# image_obj["file_name"] template_2_dekra/2017-12-04 Wiederkehrende Prüfung, Aufzug Nr. 5291844, DEKRA (4016)/page_0.jpg 211
# image_obj["file_name"] template_2_dekra/2018-02-19 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016) (1)/page_0.jpg 212
# image_obj["file_name"] template_2_dekra/2018-02-19 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016) (1)/page_1.jpg 213
# image_obj["file_name"] template_2_dekra/2018-02-19 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016)/page_0.jpg 214
# image_obj["file_name"] template_2_dekra/2018-02-19 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016)/page_1.jpg 215
# image_obj["file_name"] template_2_dekra/2018-03-20 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016) (1)/page_0.jpg 216
# image_obj["file_name"] template_2_dekra/2018-03-20 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016) (1)/page_1.jpg 217
# image_obj["file_name"] template_2_dekra/2018-03-20 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016)/page_0.jpg 218
# image_obj["file_name"] template_2_dekra/2018-03-20 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016)/page_1.jpg 219
# image_obj["file_name"] template_2_dekra/2018-03-21 Prüfbericht, Aufzug 47NAL566, DEKRA (9511)/page_0.jpg 220
# image_obj["file_name"] template_2_dekra/2018-03-21 Prüfbericht, Aufzug 47NAL567, DEKRA (9511)/page_0.jpg 221
# image_obj["file_name"] template_2_dekra/2018-03-21 Prüfbericht, Aufzug 47NAL568, DEKRA (9511)/page_0.jpg 222
# image_obj["file_name"] template_2_dekra/2018-03-21 Prüfbericht, Aufzug 47NAL569, DEKRA (9511)/page_0.jpg 223
# image_obj["file_name"] template_2_dekra/2018-03-21 Prüfbericht, Aufzug 47NAL570, DEKRA (9511)/page_0.jpg 224
# image_obj["file_name"] template_2_dekra/2018-03-21 Prüfbericht, Aufzug 47NAL571, DEKRA (9511)/page_0.jpg 225
# image_obj["file_name"] template_2_dekra/2018-03-21 Prüfbericht, Aufzug 47NAL572, DEKRA (9511)/page_0.jpg 226
# image_obj["file_name"] template_2_dekra/2018-03-21 Prüfbericht, Aufzug 47NAL573, DEKRA (9511)/page_0.jpg 227
# image_obj["file_name"] template_2_dekra/2018-11-26 Zwischenprüfung, Aufzug Nr. 5291844, DEKRA (4016)/page_0.jpg 228
# image_obj["file_name"] template_2_dekra/2018-11-26 Zwischenprüfung, Aufzug Nr. 5291844, DEKRA (4016)/page_1.jpg 229
# image_obj["file_name"] template_2_dekra/2018-11-26 Zwischenprüfung, Aufzug Nr. 5291844, DEKRA (4016)/page_2.jpg 230
# image_obj["file_name"] template_2_dekra/2018-11-26 Zwischenprüfung, Aufzug Nr. 5291844, DEKRA (4016)/page_3.jpg 231
# image_obj["file_name"] template_2_dekra/2018-11-26 Zwischenprüfung, Aufzug Nr. 5291844, DEKRA (4016)/page_4.jpg 232
# image_obj["file_name"] template_2_dekra/2018-11-26 Zwischenprüfung, Aufzug Nr. 5291844, DEKRA (4016)/page_5.jpg 233
# image_obj["file_name"] template_2_dekra/2018-12-03 Prüfbescheinigung Aufzug 6118, Dekra, (WE 8074)/page_0.jpg 234
# image_obj["file_name"] template_2_dekra/2018-12-03 Prüfbescheinigung Aufzug 6118, Dekra, (WE 8074)/page_1.jpg 235
# image_obj["file_name"] template_2_dekra/2018-12-03 Prüfbescheinigung Aufzug 6120, Dekra, (WE 8074)/page_0.jpg 236
# image_obj["file_name"] template_2_dekra/2018-12-03 Prüfbescheinigung Aufzug 6120, Dekra, (WE 8074)/page_1.jpg 237
# image_obj["file_name"] template_2_dekra/2019-06-14 Prüfbescheinigung DEKRA, Aufzug 1118361 (1172)/page_0.jpg 238
# image_obj["file_name"] template_2_dekra/2020-01-15 Prüfbescheinigung 6118, DEKRA, (WE 8074)/page_0.jpg 239
# image_obj["file_name"] template_2_dekra/2020-01-15 Prüfbescheinigung 6118, DEKRA, (WE 8074)/page_1.jpg 240
# image_obj["file_name"] template_2_dekra/2020-01-15 Prüfbescheinigung 6119, DEKRA, (WE 8074)/page_0.jpg 241
# image_obj["file_name"] template_2_dekra/2020-01-15 Prüfbescheinigung 6119, DEKRA, (WE 8074)/page_1.jpg 242
# image_obj["file_name"] template_2_dekra/2020-01-15 Prüfbescheinigung 6120 DEKRA, (WE 8074)/page_0.jpg 243
# image_obj["file_name"] template_2_dekra/2020-01-15 Prüfbescheinigung 6120 DEKRA, (WE 8074)/page_1.jpg 244
# image_obj["file_name"] template_2_dekra/2020-01-15 Prüfbescheinigung 7526, DEKRA, (WE 8074)/page_0.jpg 245
# image_obj["file_name"] template_2_dekra/2020-01-15 Prüfbescheinigung 7526, DEKRA, (WE 8074)/page_1.jpg 246
# image_obj["file_name"] template_2_dekra/2020-01-15 Prüfbescheinigung 8464, DEKRA, (WE 8074)/page_0.jpg 247
# image_obj["file_name"] template_2_dekra/2020-01-15 Prüfbescheinigung 8464, DEKRA, (WE 8074)/page_1.jpg 248
# image_obj["file_name"] template_2_dekra/2020-01-22 Prüfung Aufzug 302097, Dekra/page_0.jpg 249
# image_obj["file_name"] template_2_dekra/2020-01-22 Prüfung Aufzug 302097, Dekra/page_1.jpg 250
# image_obj["file_name"] template_2_dekra/2020-01-22 Prüfung Aufzug 302098, Dekra/page_0.jpg 251
# image_obj["file_name"] template_2_dekra/2020-01-22 Prüfung Aufzug 302098, Dekra/page_1.jpg 252
# image_obj["file_name"] template_2_dekra/2020-01-22 Prüfung Aufzug 302099, Dekra/page_0.jpg 253
# image_obj["file_name"] template_2_dekra/2020-01-22 Prüfung Aufzug 302099, Dekra/page_1.jpg 254
# image_obj["file_name"] template_2_dekra/2020-01-22 Prüfung Aufzug 302101, Dekra/page_0.jpg 255
# image_obj["file_name"] template_2_dekra/2020-01-22 Prüfung Aufzug 302101, Dekra/page_1.jpg 256
# image_obj["file_name"] template_2_dekra/2020-02-19 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016) (1)/page_0.jpg 257
# image_obj["file_name"] template_2_dekra/2020-02-19 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016)/page_0.jpg 258
# image_obj["file_name"] template_2_dekra/2020-05-19 Wiederkehrende Prüfung Nachprüfung, Aufzug Nr. 5291844, DEKRA (4016)/page_0.jpg 259
# image_obj["file_name"] template_2_dekra/2021-03-11 Zwischenprüfung, Aufzug Nr. 5291840, DEKRA (4016) (1)/page_0.jpg 260
# image_obj["file_name"] template_2_dekra/2021-03-11 Zwischenprüfung, Aufzug Nr. 5291840, DEKRA (4016)/page_0.jpg 261
# image_obj["file_name"] template_2_dekra/2021-05-28 Hauptprüfung Aufzug F  1118361/page_0.jpg 262
# image_obj["file_name"] template_2_dekra/2021-05-28 Hauptprüfung Aufzug F  1118361/page_1.jpg 263
# image_obj["file_name"] template_2_dekra/2021-10-26 Zwischenprüfung Güter1118375/page_0.jpg 264
# image_obj["file_name"] template_2_dekra/2021-10-26 Zwischenprüfung Güter1118375/page_1.jpg 265
# image_obj["file_name"] template_2_dekra/2022-02-23 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016) (1)/page_0.jpg 266
# image_obj["file_name"] template_2_dekra/2022-02-23 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016) (1)/page_1.jpg 267
# image_obj["file_name"] template_2_dekra/2022-02-23 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016)/page_0.jpg 268
# image_obj["file_name"] template_2_dekra/2022-02-23 Wiederkehrende Prüfung, Aufzug Nr. 5291840, DEKRA (4016)/page_1.jpg 269
# image_obj["file_name"] template_2_dekra/2022-03-28 Nachprüfung, Aufzug Nr. 5291840, DEKRA (4016) (1)/page_0.jpg 270
# image_obj["file_name"] template_2_dekra/2022-03-28 Nachprüfung, Aufzug Nr. 5291840, DEKRA (4016)/page_0.jpg 271
# image_obj["file_name"] template_2_dekra/2022-04-19 Hauptprüfung Aufzug 6118, Dekra (8074)/page_0.jpg 272
# image_obj["file_name"] template_2_dekra/2022-04-19 Hauptprüfung Aufzug 6118, Dekra (8074)/page_1.jpg 273
# image_obj["file_name"] template_2_dekra/2022-04-19 Hauptprüfung Aufzug 6120, Dekra (8074)/page_0.jpg 274
# image_obj["file_name"] template_2_dekra/2022-04-19 Hauptprüfung Aufzug 6120, Dekra (8074)/page_1.jpg 275
# image_obj["file_name"] template_2_dekra/2022-04-19 Hauptprüfung Aufzug 7525, Dekra (8074)/page_0.jpg 276
# image_obj["file_name"] template_2_dekra/2022-04-19 Hauptprüfung Aufzug 7525, Dekra (8074)/page_1.jpg 277
# image_obj["file_name"] template_2_dekra/2022-04-19 Hauptprüfung Aufzug 7526, Dekra (8074)/page_0.jpg 278
# image_obj["file_name"] template_2_dekra/2022-04-19 Hauptprüfung Aufzug 7526, Dekra (8074)/page_1.jpg 279
# image_obj["file_name"] template_2_dekra/2022-04-19 Hauptprüfung Aufzug 8464, Dekra (8074)/page_0.jpg 280
# image_obj["file_name"] template_2_dekra/2022-04-19 Hauptprüfung Aufzug 8464, Dekra (8074)/page_1.jpg 281
# image_obj["file_name"] template_2_dekra/2022-04-20 Hauptprüfung Aufzug 6119, Dekra (8074)/page_0.jpg 282
# image_obj["file_name"] template_2_dekra/2022-04-20 Hauptprüfung Aufzug 6119, Dekra (8074)/page_1.jpg 283
# image_obj["file_name"] template_2_dekra/2022-04-20 Hauptprüfung Aufzug 7524, Dekra (8074)/page_0.jpg 284
# image_obj["file_name"] template_2_dekra/2022-04-20 Hauptprüfung Aufzug 7524, Dekra (8074)/page_1.jpg 285
# image_obj["file_name"] template_2_dekra/2022-05-04 Prüfbericht, Aufzug HS 45, Dekra (9511)/page_0.jpg 286
# image_obj["file_name"] template_2_dekra/2022-05-04 Prüfbericht, Aufzug HS 45, Dekra (9511)/page_1.jpg 287
# image_obj["file_name"] template_2_dekra/2022-05-04 Prüfbericht, Aufzug HS 47, Dekra (9511)/page_0.jpg 288
# image_obj["file_name"] template_2_dekra/2022-05-04 Prüfbericht, Aufzug HS 47, Dekra (9511)/page_1.jpg 289
# image_obj["file_name"] template_2_dekra/2022-05-04 Prüfbericht, Aufzug HS 51, Dekra (9511)/page_0.jpg 290
# image_obj["file_name"] template_2_dekra/2022-05-04 Prüfbericht, Aufzug HS 51, Dekra (9511)/page_1.jpg 291
# image_obj["file_name"] template_2_dekra/2022-10-04 Hauptprüfung Lastenaufzug 1118375/page_0.jpg 292
# image_obj["file_name"] template_2_dekra/2022-10-04 Hauptprüfung Lastenaufzug 1118375/page_1.jpg 293
# image_obj["file_name"] template_2_dekra/2023-02-14 Zwischenprüfung, Aufzug Nr. 5291840, DEKRA (4016) (1)/page_0.jpg 294
# image_obj["file_name"] template_2_dekra/2023-02-14 Zwischenprüfung, Aufzug Nr. 5291840, DEKRA (4016) (1)/page_1.jpg 295
# image_obj["file_name"] template_2_dekra/2023-02-14 Zwischenprüfung, Aufzug Nr. 5291840, DEKRA (4016)/page_0.jpg 296
# image_obj["file_name"] template_2_dekra/2023-02-14 Zwischenprüfung, Aufzug Nr. 5291840, DEKRA (4016)/page_1.jpg 297
# image_obj["file_name"] template_2_dekra/3034183001317-20220428/page_0.jpg 298
# image_obj["file_name"] template_2_dekra/3034183001317-20220428/page_1.jpg 299
# image_obj["file_name"] template_2_dekra/3034183001326-20220428/page_0.jpg 300
# image_obj["file_name"] template_2_dekra/3034183001326-20220428/page_1.jpg 301
# image_obj["file_name"] template_2_dekra/3034183001327-20220428/page_0.jpg 302
# image_obj["file_name"] template_2_dekra/3034183001327-20220428/page_1.jpg 303
# image_obj["file_name"] template_2_dekra/3034183001328-20220428/page_0.jpg 304
# image_obj["file_name"] template_2_dekra/3034183001328-20220428/page_1.jpg 305
# populating valid image indices
# image_obj["file_name"] template_3_TUV_Nord/2010-04-26 Prüfbericht, Personenaufzug 88938 und 88939, TÜV Nord (7006)/page_0.jpg 265
# image_obj["file_name"] template_3_TUV_Nord/2010-04-26 Prüfbericht, Personenaufzug 88938 und 88939, TÜV Nord (7006)/page_1.jpg 266
# image_obj["file_name"] template_3_TUV_Nord/2011-02-22 TÜV-Bericht, Zwischenprüfung Aufzug Nr. 88938, TÜV Nord (7006)/page_0.jpg 267
# image_obj["file_name"] template_3_TUV_Nord/2011-02-22 TÜV-Bericht, Zwischenprüfung Aufzug Nr. 88939, TÜV Nord (7006)/page_0.jpg 268
# image_obj["file_name"] template_3_TUV_Nord/2011-03-16 Zwischenprüfung, Aufzug Nr 5291846 und 5291845, TÜV Nord (4016)/page_0.jpg 269
# image_obj["file_name"] template_3_TUV_Nord/2011-03-16 Zwischenprüfung, Aufzug Nr 5291846 und 5291845, TÜV Nord (4016)/page_1.jpg 270
# image_obj["file_name"] template_3_TUV_Nord/2011-03-16 Zwischenprüfung, Aufzug Nr 5291846 und 5291845, TÜV Nord (4016)/page_2.jpg 271
# image_obj["file_name"] template_3_TUV_Nord/2011-03-16 Zwischenprüfung, Aufzug Nr 5291846 und 5291845, TÜV Nord (4016)/page_3.jpg 272
# image_obj["file_name"] template_3_TUV_Nord/2011-03-16 Zwischenprüfung, Aufzug Nr 5291846 und 5291845, TÜV Nord (4016)/page_4.jpg 273
# image_obj["file_name"] template_3_TUV_Nord/2011-03-16 Zwischenprüfung, Aufzug Nr 5291846 und 5291845, TÜV Nord (4016)/page_5.jpg 274
# image_obj["file_name"] template_3_TUV_Nord/2011-03-16 Zwischenprüfung, Aufzug Nr. 5291846 und 5291845, TÜV Nord (4016)/page_0.jpg 275
# image_obj["file_name"] template_3_TUV_Nord/2011-03-16 Zwischenprüfung, Aufzug Nr. 5291846 und 5291845, TÜV Nord (4016)/page_1.jpg 276
# image_obj["file_name"] template_3_TUV_Nord/2011-03-16 Zwischenprüfung, Aufzug Nr. 5291846 und 5291845, TÜV Nord (4016)/page_2.jpg 277
# image_obj["file_name"] template_3_TUV_Nord/2011-03-16 Zwischenprüfung, Aufzug Nr. 5291846 und 5291845, TÜV Nord (4016)/page_3.jpg 278
# image_obj["file_name"] template_3_TUV_Nord/2011-03-16 Zwischenprüfung, Aufzug Nr. 5291846 und 5291845, TÜV Nord (4016)/page_4.jpg 279
# image_obj["file_name"] template_3_TUV_Nord/2011-03-16 Zwischenprüfung, Aufzug Nr. 5291846 und 5291845, TÜV Nord (4016)/page_5.jpg 280
# image_obj["file_name"] template_3_TUV_Nord/2012-02-10 Prüfbescheinigung, Hebebühne 6225-5-2009, TÜV Nord (4074)/page_0.jpg 281
# image_obj["file_name"] template_3_TUV_Nord/2012-02-28  Wiederkehrende Prüfung, Aufzug Nr. 5291845, TÜV Nord (4016)/page_0.jpg 282
# image_obj["file_name"] template_3_TUV_Nord/2012-02-28 Wiederkehrende Prüfung, Aufzug Nr. 5291840, TÜV-Nord (4016)/page_0.jpg 283
# image_obj["file_name"] template_3_TUV_Nord/2012-02-28 Wiederkehrende Prüfung, Aufzug Nr. 5291846, TÜV-Nord (4016)/page_0.jpg 284
# image_obj["file_name"] template_3_TUV_Nord/2012-07-13 Wiederkehrende Prüfung, Aufzug Nr. 5291847, TÜV Nord (4016)/page_0.jpg 285
# image_obj["file_name"] template_3_TUV_Nord/2012-07-13 Wiederkehrende Prüfung, Aufzug Nr. 5291847, TÜV Nord (4016)/page_1.jpg 286
# image_obj["file_name"] template_3_TUV_Nord/2012-10-12 Prüfbericht, Neubau - Aufzug Nummer 1118365, TÜV Nord (1172)/page_0.jpg 287
# image_obj["file_name"] template_3_TUV_Nord/2012-10-12 Prüfbericht, Neubau - Aufzug Nummer 1118370, TÜV Nord (1172)/page_0.jpg 288
# image_obj["file_name"] template_3_TUV_Nord/2012-10-12 Prüfbericht, Neubau - Aufzug Nummer 1118372, TÜV Nord (1172)/page_0.jpg 289
# image_obj["file_name"] template_3_TUV_Nord/2012-11-14 Prüfbericht, Neubau - Aufzug Nummer 1118361, TÜV Nord (1172)/page_0.jpg 290
# image_obj["file_name"] template_3_TUV_Nord/2012-11-14 Prüfbericht, Neubau - Aufzug Nummer 1118373, TÜV Nord (1172)/page_0.jpg 291
# image_obj["file_name"] template_3_TUV_Nord/2012-11-14 Prüfbericht, Neubau - Aufzug Nummer 1118374, TÜV Nord (1172)/page_0.jpg 292
# image_obj["file_name"] template_3_TUV_Nord/2012-11-16 Prüfbericht, Neubau - Aufzug Nummer 1118359, TÜV Nord (1172)/page_0.jpg 293
# image_obj["file_name"] template_3_TUV_Nord/2012-11-16 Prüfbericht, Neubau - Aufzug Nummer 1118360, TÜV Nord (1172)/page_0.jpg 294
# image_obj["file_name"] template_3_TUV_Nord/2013-02-07 Prüfbescheinigung Personenaufzug, Nr. 88938, TÜV Nord (7006)/page_0.jpg 295
# image_obj["file_name"] template_3_TUV_Nord/2013-02-22 Prüfbericht, Neubau - Güteraufzug Nummer 1118375, TÜV Nord (1172)/page_0.jpg 296
# image_obj["file_name"] template_3_TUV_Nord/2013-03-19 Zwischenprüfung, Aufzug Nr. 5291839, Tüv Nord (4016)/page_0.jpg 297
# image_obj["file_name"] template_3_TUV_Nord/2013-03-19 Zwischenprüfung, Aufzug Nr. 5291840, Tüv Nord (4016)/page_0.jpg 298
# image_obj["file_name"] template_3_TUV_Nord/2013-03-19 Zwischenprüfung, Aufzug Nr. 5291845, Tüv Nord (4016)/page_0.jpg 299
# image_obj["file_name"] template_3_TUV_Nord/2013-03-19 Zwischenprüfung, Aufzug Nr. 5291846, Tüv Nord (4016)/page_0.jpg 300
# image_obj["file_name"] template_3_TUV_Nord/2013-05-22 Prüfbericht, Neubau - Aufzug Nummer 1118361, TÜV Nord (1172)/page_0.jpg 301
# image_obj["file_name"] template_3_TUV_Nord/2013-07-29 Zwischenprüfung, Aufzug Nr. 5291847, TÜV NORD (4016)/page_0.jpg 302
# image_obj["file_name"] template_3_TUV_Nord/2013-10-17 Prüfbericht, Neubau - Aufzug Nummer 1118373, TÜV Nord (1172)/page_0.jpg 303
# image_obj["file_name"] template_3_TUV_Nord/2013-10-17 Prüfbericht, Neubau - Aufzug Nummer 1118374, TÜV Nord (1172)/page_0.jpg 304
# image_obj["file_name"] template_3_TUV_Nord/2013-10-18 Prüfbericht, Neubau - Aufzug Nummer 1118359, TÜV Nord (1172)/page_0.jpg 305
# image_obj["file_name"] template_3_TUV_Nord/2013-10-18 Prüfbericht, Neubau - Aufzug Nummer 1118360, TÜV Nord (1172)/page_0.jpg 306
# image_obj["file_name"] template_3_TUV_Nord/2013-10-31 Prüfbericht, Neubau - Aufzug Nummer 10493061, TÜV Nord (1172)/page_0.jpg 307
# image_obj["file_name"] template_3_TUV_Nord/2013-11-01 Prüfbericht, Neubau - Aufzug Nummer 10493063, TÜV Nord (1172)/page_0.jpg 308
# image_obj["file_name"] template_3_TUV_Nord/2013-11-01 Prüfbericht, Neubau - Aufzug Nummer 10513342, TÜV Nord (1172)/page_0.jpg 309
# image_obj["file_name"] template_3_TUV_Nord/2013-11-11 Wiederkehrende Prüfung, Aufzug Nr. 5291843, Tüv Nord (4016)/page_0.jpg 310
# image_obj["file_name"] template_3_TUV_Nord/2013-11-11 Wiederkehrende Prüfung, Aufzug Nr. 5291844, TÜV NORD (4016)/page_0.jpg 311
# image_obj["file_name"] template_3_TUV_Nord/2014-02-28 Prüfbescheinigung, Hebebühne 6225-5-2009, TÜV Nord (4074)/page_0.jpg 312
# image_obj["file_name"] template_3_TUV_Nord/2014-03-25 Wiederkehrende Prüfung, Aufzug Nr. 5291839, TÜV Nord (4016)/page_0.jpg 313
# image_obj["file_name"] template_3_TUV_Nord/2014-03-25 Wiederkehrende Prüfung, Aufzug Nr. 5291840, TÜV Nord (4016)/page_0.jpg 314
# image_obj["file_name"] template_3_TUV_Nord/2014-03-25 Wiederkehrende Prüfung, Aufzug Nr. 5291845, TÜV Nord (4016)/page_0.jpg 315
# image_obj["file_name"] template_3_TUV_Nord/2014-03-25 Wiederkehrende Prüfung, Aufzug Nr. 5291846, TÜV Nord (4016)/page_0.jpg 316
# image_obj["file_name"] template_3_TUV_Nord/2014-04-10_Hauptprüfung Aufzug 88938, TÜV Nord (7006)/page_0.jpg 317
# image_obj["file_name"] template_3_TUV_Nord/2014-04-10_WiederkehrendePruef_88939/page_0.jpg 318
# image_obj["file_name"] template_3_TUV_Nord/2014-05-08 Prüfbericht, Neubau - Aufzug Nummer 1118365, TÜV Nord (1172)/page_0.jpg 319
# image_obj["file_name"] template_3_TUV_Nord/2014-05-08 Prüfbericht, Neubau - Aufzug Nummer 1118370, TÜV Nord (1172)/page_0.jpg 320
# image_obj["file_name"] template_3_TUV_Nord/2014-05-08 Prüfbericht, Neubau - Zwischenprüfung - Aufzug Nummer 1118372, TÜV Nord (1172)/page_0.jpg 321
# image_obj["file_name"] template_3_TUV_Nord/2014-07-07 Wiederkehrende Prüfung, Aufzug Nr. 5291847, TÜV Nord (4016)/page_0.jpg 322
# image_obj["file_name"] template_3_TUV_Nord/2014-07-07 Wiederkehrende Prüfung, Aufzug Nr. 5291847, TÜV Nord (4016)/page_1.jpg 323
# image_obj["file_name"] template_3_TUV_Nord/2014-09-18 Prüfbericht, Neubau - Zwischenprüfung - Aufzug Nummer 10493061, TÜV Nord (1172)/page_0.jpg 324
# image_obj["file_name"] template_3_TUV_Nord/2014-09-18 Prüfbericht, Neubau - Zwischenprüfung - Aufzug Nummer 10493063, TÜV Nord (1172)/page_0.jpg 325
# image_obj["file_name"] template_3_TUV_Nord/2014-09-18 Prüfbericht, Neubau - Zwischenprüfung - Aufzug Nummer 10513342, TÜV Nord (1172)/page_0.jpg 326
# image_obj["file_name"] template_3_TUV_Nord/2014-09-22_Vorprüfung vor Änderung Aufzug 88938, TÜV Nord (7006)/page_0.jpg 327
# image_obj["file_name"] template_3_TUV_Nord/2014-11-11 Prüfbericht, Neubau - Zwischenprüfung - Aufzug Nummer 1118359, TÜV Nord (1172)/page_0.jpg 328
# image_obj["file_name"] template_3_TUV_Nord/2014-11-11 Prüfbericht, Neubau - Zwischenprüfung - Aufzug Nummer 1118360, TÜV Nord (1172)/page_0.jpg 329
# image_obj["file_name"] template_3_TUV_Nord/2014-11-11 Prüfbericht, Neubau - Zwischenprüfung - Aufzug Nummer 1118361, TÜV Nord (1172)/page_0.jpg 330
# image_obj["file_name"] template_3_TUV_Nord/2014-11-12 Prüfbericht, Neubau - Zwischenprüfung - Aufzug Nummer 1118373, TÜV Nord (1172)/page_0.jpg 331
# image_obj["file_name"] template_3_TUV_Nord/2014-11-12 Prüfbericht, Neubau - Zwischenprüfung - Aufzug Nummer 1118374, TÜV Nord (1172)/page_0.jpg 332
# image_obj["file_name"] template_3_TUV_Nord/2014-11-20_Nachprüfung Aufzug 88938, TÜV Nord (7006)/page_0.jpg 333
# image_obj["file_name"] template_3_TUV_Nord/2014-11-20_Prüfung nach Änderung Aufzug 88938, TÜV Nord (7006)/page_0.jpg 334
# image_obj["file_name"] template_3_TUV_Nord/2014-11-25 Prüfbericht, Neubau - Aufzug Nummer 1118365, TÜV Nord (1172)/page_0.jpg 335
# image_obj["file_name"] template_3_TUV_Nord/2014-11-26 Prüfbericht, Neubau - Aufzug Nummer 1118370, TÜV Nord (1172)/page_0.jpg 336
# image_obj["file_name"] template_3_TUV_Nord/2014-11-26 Prüfbericht, Neubau - Aufzug Nummer 1118372, TÜV Nord (1172)/page_0.jpg 337
# image_obj["file_name"] template_3_TUV_Nord/2015-01-08 Zwischenprüfung, Aufzug Nr. 5291843, TÜV Nord (4016)/page_0.jpg 338
# image_obj["file_name"] template_3_TUV_Nord/2015-01-08 Zwischenprüfung, Aufzug Nr. 5291844, TÜV Nord (4016)/page_0.jpg 339
# image_obj["file_name"] template_3_TUV_Nord/2015-01-08 Zwischenprüfung, Aufzug Nr. 5291845, TÜV Nord (4016)/page_0.jpg 340
# image_obj["file_name"] template_3_TUV_Nord/2015-01-08 Zwischenprüfung, Aufzug Nr. 5291846, TÜV Nord (4016)/page_0.jpg 341
# image_obj["file_name"] template_3_TUV_Nord/2015-03-25 Zwischenprüfung, Aufzug Nr. 5291839, TÜV Nord (4016)/page_0.jpg 342
# image_obj["file_name"] template_3_TUV_Nord/2015-03-25 Zwischenprüfung, Aufzug Nr. 5291840, TÜV Nord (4016)/page_0.jpg 343
# image_obj["file_name"] template_3_TUV_Nord/2015-07-20 Zwischenprüfung, Aufzug Nr. 5291847, TÜV Nord (4016)/page_0.jpg 344
# image_obj["file_name"] template_3_TUV_Nord/2016-02-09 Prüfaufzeichnung, Hebebühne 6225-5-2009, TÜV Nord (4074)/page_0.jpg 345
# image_obj["file_name"] template_3_TUV_Nord/2016-02-10 Wiederkehrende Prüfung, Aufzug Nr. 5291839, TÜV Nord (4016)/page_0.jpg 346
# image_obj["file_name"] template_3_TUV_Nord/2016-02-10 Wiederkehrende Prüfung, Aufzug Nr. 5291840, TÜV Nord (4016)/page_0.jpg 347
# image_obj["file_name"] template_3_TUV_Nord/2016-02-10 Wiederkehrende Prüfung, Aufzug Nr. 5291845, TÜV Nord (4016)/page_0.jpg 348
# image_obj["file_name"] template_3_TUV_Nord/2016-02-10 Wiederkehrende Prüfung, Aufzug Nr. 5291846, TÜV Nord (4016)/page_0.jpg 349
# image_obj["file_name"] template_3_TUV_Nord/2016-08-17 Wiederkehrende Prüfung, Aufzug Nr. 5291847 O1, TÜV NORD (4016)/page_0.jpg 350
# image_obj["file_name"] template_3_TUV_Nord/2016-11-24 Zwischenprüfung, Aufzug Nr. 5291843, TÜV NORD (4016)/page_0.jpg 351
# image_obj["file_name"] template_3_TUV_Nord/2016-11-24 Zwischenprüfung, Aufzug Nr. 5291843, TÜV NORD (4016)/page_1.jpg 352
# image_obj["file_name"] template_3_TUV_Nord/2016-11-24 Zwischenprüfung, Aufzug Nr. 5291843, TÜV NORD (4016)/page_2.jpg 353
_ids_197.p', 'input_ids_198.p', 'input_ids_199.p', 'input_ids_200.p', 'input_ids_201.p', 'input_ids_202.p', 'input_ids_203.p', 'input_ids_204.p', 'input_ids_205.p', 'input_ids_206.p', 'input_ids_207.p', 'input_ids_208.p', 'input_ids_209.p', 'input_ids_210.p', 'input_ids_211.p', 'input_ids_212.p', 'input_ids_214.p', 'input_ids_216.p', 'input_ids_218.p', 'input_ids_220.p', 'input_ids_221.p', 'in ...

# %%
tokenizer_dir = 'tokenizer_added_tokens_all'
model_dir = 'model_added_tokens_all'
#shutil.rmtree(tokenizer_dir)
#shutil.rmtree(model_dir)
tokenizer.save_pretrained(tokenizer_dir)
model.save_pretrained(model_dir)

# %% [markdown]
# ## Checking if the format is correct

# %%
dataset_reference = 'dataset_b2'
dataset_test = 'dataset_real'

bbox_path_reference = f'{dataset_reference}/train/bbox/bbox_0.p'
bbox_path_test = f'{dataset_test}/train/bbox/bbox_0.p'

image_path_reference = f'{dataset_reference}/train/images/image_0.jpeg'
image_path_test = f'{dataset_test}/train/images/image_0.jpeg'

images_resized_path_reference = f'{dataset_reference}/train/images_resized/image_0.jpeg'
images_resized_path_test = f'{dataset_test}/train/images_resized/image_resized_0.jpeg'

input_ids_path_reference = f'{dataset_reference}/train/input_ids/input_ids_0.p'
input_ids_path_test = f'{dataset_test}/train/input_ids/input_ids_0.p'

labels_path_reference = f'{dataset_reference}/train/labels/labels_0.p'
labels_path_test = f'{dataset_test}/train/labels/labels_0.p'

entities_path_reference = f'{dataset_reference}/train/entities/entities_1.p'
entities_path_test = f'{dataset_test}/train/entities/entities_1.p'

relations_path_reference = f'{dataset_reference}/train/relations/relations_1.p'
relations_path_test = f'{dataset_test}/train/relations/relations_1.p'

with open(bbox_path_reference, 'rb') as f:
    bbox_reference = pickle.load(f)    
with open(bbox_path_test, 'rb') as f:
    bbox_test = pickle.load(f)



image_reference = cv2.imread(image_path_reference)
image_test = cv2.imread(image_path_test)
    
image_resized_reference = cv2.imread(images_resized_path_reference)
image_resized_test = cv2.imread(images_resized_path_test)
    
with open(labels_path_reference, 'rb') as f:
    label_reference = pickle.load(f)
with open(labels_path_test, 'rb') as f:
    label_test = pickle.load(f)
    
with open(input_ids_path_reference, 'rb') as f:
    input_id_reference = pickle.load(f)
with open(input_ids_path_test, 'rb') as f:
    input_id_test = pickle.load(f)
    
with open(entities_path_reference, 'rb') as f:
    entities_reference = pickle.load(f)
with open(entities_path_test, 'rb') as f:
    entities_test = pickle.load(f)
    
with open(relations_path_reference, 'rb') as f:
    relations_reference = pickle.load(f)
with open(relations_path_test, 'rb') as f:
    relations_test = pickle.load(f)
    
    
    
    

## bbox
print('bbox')
print(np.array(bbox_reference).shape) 
print(np.array(bbox_test).shape)
print('-----')

## image
print('image')
print(image_reference.shape) 
print(image_test.shape)
print('-----')

## image_resized
print('image_resized')
print(image_resized_reference.shape) 
print(image_resized_test.shape)
print('--------')

## input_ids
print('input_ids')
print(np.array(input_id_reference).shape) 
print(np.array(input_id_test).shape)
print('-------')

## labels
print('labels')
print(np.array(label_reference).shape) 
print(np.array(label_test).shape)
print('--------')

## entities
print('entities')
print(entities_reference) 
print(entities_test)
print('-------')

## relations
print('relations')
print(relations_reference) 
print(relations_test) 
print('-------')

# %% [markdown]
# ## Testing relations and entities

# %%
index = 332
entities_path = f'dataset_real_no_re/train/entities/entities_{index}.p'
with open(entities_path, 'rb') as f:
    entities = pickle.load(f)

relations_path = f'dataset_real_no_re/train/relations/relations_{index}.p'

with open(relations_path, 'rb') as f:
    relations = pickle.load(f)
    
input_ids_path = f'dataset_real_no_re/train/input_ids/input_ids_{index}.p'

with open(input_ids_path, 'rb') as f:
    input_ids = pickle.load(f)

#print(relations)
#print(entities)

entities_names = []
entities_with_boxes = []
for i , (start, end) in enumerate(zip(entities['start'], entities['end'])):
    #print(f'{i}, {tokenizer.decode(input_ids[start:end])} : {entities["label"][i]} {entities["cat"][i]}')
    #if entities["label"][i].lower() != 'other':
    entities_names.append(tokenizer.decode(input_ids[start:end]))
  #entities_names.append(tokenizer.decode(input_ids[start:end]))

for i in range(len(relations['head'])):
    print(f'question : {entities_names[relations["head"][i]]}, Answer :  {entities_names[relations["tail"][i]]}, start: {relations["head"][i]}, end: {relations["tail"][i]}')
# Out:
# question : equipment-nummer, Answer :  10278559, start: 4, end: 3
# question : leistungsort, Answer :  emporiotowerdammtorwall 1520355hamburg, start: 5, end: 24
# question : prüfdatum, Answer :  12.11.2014, start: 6, end: 18
# question : prüfort, Answer :  hamburg, start: 7, end: 17
# question : fabrik-/herstell-nr, Answer :  1118374, start: 8, end: 23
# question : baujahr, Answer :  2010, start: 9, end: 22
# question : tragfähigkeit, Answer :  1350 kg, start: 10, end: 21
# question : auftrags-nummer, Answer :  8111454909-000110, start: 12, end: 2
# question : hersteller, Answer :  schindleraufzüge, start: 15, end: 20
# question : prüfergebnis, Answer :  ohnemängel, start: 16, end: 19
# question : akten-nummer, Answer :  88206-035419, start: 26, end: 25
# question : kunden-nummer, Answer :  0055026449, start: 28, end: 27

# %% [markdown]
# ## Testing bboxes without dataset class

# %%
index = 20

image = cv2.imread(f'dataset/train/images/image_{index}.jpeg')
bbox_path = f'dataset/train/bbox/bbox_{index}.p'
with open(bbox_path, 'rb') as f:
    bbox = pickle.load(f)

def unnormalize_box(bbox, width, height):
     return [
         width * (bbox[0] / 1000),
         height * (bbox[1] / 1000),
         width * (bbox[2] / 1000),
         height * (bbox[3] / 1000),
     ]

image = Image.fromarray(image)
width, height = image.size
print(width)
print(height)

true_boxes = [unnormalize_box(box, width, height) for idx, box in enumerate(bbox)]
image = np.array(image)
for box in true_boxes:
  box = [int(i) for i in box]
  cv2.rectangle(image, (box[0], box[1]), (box[2], box[3]), (0, 255, 0), 2)
plt.imshow(image)

# %% [markdown]
# ## Testing bboxes

# %%
from dataset_creator import *

configs_train = {
    "num_files":30,
    "images_dir" : "images",
    "images_resized_dir" : "images_resized",
    "bbox_dir":"bbox",
    "input_ids_dir" : "input_ids",
    "labels_dir" : "labels",
    "entities_dir" : "entities",
    "relations_dir" : "relations",
    "type":"train",
    "clear_all_old_files" : True,
    "clear_old_files_type": [True, "validation"]
}

configs_validation = {
    "num_files":30,
    "images_dir" : "images",
    "images_resized_dir" : "images_resized",
    "bbox_dir":"bbox",
    "input_ids_dir" : "input_ids",
    "labels_dir" : "labels",
    "entities_dir" : "entities",
    "relations_dir" : "relations",
    "type":"validation",
    "clear_all_old_files" : True,
    "clear_old_files_type": [True, "validation"]
}

configs_train = {key:val for key,val in configs_train.items() if key not in ("num_files", "clear_all_old_files", "clear_old_files_type")}
configs_validation = {key:val for key,val in configs_validation.items() if key not in ("num_files", "clear_all_old_files", "clear_old_files_type")}

dataset_train = Custom_Dataset(**configs_train)
dataset_validation = Custom_Dataset(**configs_validation)

# %%
sample = dataset_train[1]
image = sample['original_image']
image.shape
bbox = sample['bbox']
bbox

# %%
def unnormalize_box(bbox, width, height):
     return [
         width * (bbox[0] / 1000),
         height * (bbox[1] / 1000),
         width * (bbox[2] / 1000),
         height * (bbox[3] / 1000),
     ]

#predictions = outputs.logits.argmax(-1).squeeze().tolist()
#token_boxes = encoding.bbox.squeeze().tolist()

image = Image.fromarray(image)
width, height = image.size
print(width)
print(height)

# %%
from PIL import ImageDraw, ImageFont


draw = ImageDraw.Draw(image)

font = ImageFont.load_default()
true_boxes = [unnormalize_box(box, width, height) for idx, box in enumerate(bbox)]
#true_boxes = bbox
print(true_boxes)
def iob_to_label(label):
    label = label[2:]
    if not label:
      return 'other'
    return label

label2color = {'question':'blue', 'answer':'green', 'header':'orange', 'other':'violet'}
image = np.array(image)
for box in true_boxes:
  #box = [int(i) for i in box]
  #cv2.rectangle(image, (box[0], box[1]), (box[2], box[3]), (0, 255, 0), 2)
  #draw.text((box[0]+10, box[1]-10), fill=label2color[predicted_label], font=font)
  draw.rectangle(unnormalize_box(bbox, width=width, height=height), outline='red', width=1)

# %%
plt.imshow(image)

# %% [markdown]
# ## (Optional) Combining the real dataset with synthetic dataset

# %%
synthetic_dataset_dir = 'dataset/train'
real_dataset_dir = 'dataset_real/train'

# %%
import shutil
import os

# %%
sub_dirs_synth = [os.path.join(synthetic_dataset_dir, sub_dir) for sub_dir in os.listdir(synthetic_dataset_dir)]
file_names_synth = [files for files in os.listdir(sub_dirs_synth[0])]
last_known_index_synth = [int(file[file.rfind('_')+1:file.rfind('.')]) for file in file_names_synth]
last_known_index_synth = max(last_known_index_synth)
last_known_index_synth

next_index = last_known_index_synth + 1

# %%
sub_dirs_real = [sub_dir for sub_dir in os.listdir(real_dataset_dir)]

for sub_dir in sub_dirs_real:
    sub_dir_path = os.path.join(real_dataset_dir,sub_dir)
    sorted_paths = sorted(os.listdir(sub_dir_path), key=lambda x: int(x[x.rindex("_")+1:x.rindex(".")]))
    for file in sorted_paths:
        altered_file_name = f'{file[:file.rfind("_")]}_{next_index}{file[file.rfind("."):]}'
        src_path = f'{real_dataset_dir}/{sub_dir}/{file}'
        dst_path = f'{synthetic_dataset_dir}/{sub_dir}/{altered_file_name}'
        next_index += 1
        
        shutil.copy(src_path, dst_path)
    next_index = last_known_index_synth+1
